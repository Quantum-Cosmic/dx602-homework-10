# %% [markdown]
# # DX 602 Week 10 Homework

# %% [markdown]
# ## Introduction
#
# In this homework, you will practice exploratory analysis using Pandas, and review previous material in this module.
#
# The first ten problems of this homework will be manually graded due to their visual nature.
# The remaining problems will be graded automatically like usual.

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to this GitHub repository of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx602-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Shared Imports
#
# Do not install or use any additional modules.
# Installing additional modules may result in an autograder failure resulting in zero points for some or all problems.

# %%
import math
import sys

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Shared Data

# %% [markdown]
# The following red wine data set is from the paper ["Modeling wine preferences by data mining from physicochemical properties"](https://repositorium.sdum.uminho.pt/bitstream/1822/10029/1/wine5.pdf).

# %%
red_wine = pd.read_csv("https://github.com/EpistasisLab/pmlb/raw/refs/heads/master/datasets/wine_quality_red/wine_quality_red.tsv.gz", sep="\t")
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  target
# 0      9.4       5
# 1      9.8       5
# 2      9.8       5
# 3      9.8       6
# 4      9.4       5

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1 (manually graded)
#
# Plot histograms of every column of the red wine data set in the `red_wine` variable above.
# Make sure to adjust the spacing for legibility so that the labels do not overlap the charts.

# %%
# YOUR CHANGES HERE

red_wine.hist(figsize=(15, 13), 
             bins=15, 
             alpha=0.7, 
             color='purple', 
             edgecolor='black',
             grid=True)
plt.suptitle('Red Wine Dataset', fontsize=20)
plt.tight_layout()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 2 (manually graded)
#
# Plot a scatter plot of the fixed acidity and citric acid columns of the red wine data set in the `red_wine` variable above.
# Make sure that both axes are labeled.

# %%
# YOUR CHANGES HERE

red_wine.plot.scatter(x='fixed acidity', y='citric acid', 
                      figsize=(10, 7), 
                      color='red',
                      edgecolor='black',
                      s=20,
                      grid=True)
plt.title('Citric Acid - Fixed', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Citric Acid - Fixed')

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 3 (manually graded)
#
# Repeat the scatter plot of the fixed acidity and citric acid columns of the red wine data set.
# This time, make the y axis start from zero.

# %%
# YOUR CHANGES HERE

red_wine.plot.scatter(x='fixed acidity', y='citric acid', 
                      figsize=(10, 7), 
                      color='Green',
                      edgecolor='black',
                      s=20,
                      grid=True)
plt.title('Citric Acid - Fixed', fontsize=20)
plt.ylim(0, 1.1)
# Out:
# (0.0, 1.1)

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 4 (manually graded)
#
# Plot a histogram of the `target` column of the red wine data set.
# (This column was supposed to represent the quality of the wine.)

# %%
# YOUR CHANGES HERE

red_wine.hist("target",
              figsize=(10, 7), 
             bins=10, 
             alpha=0.7, 
             color='purple', 
             edgecolor='black',
             grid=False)
plt.suptitle('Red Wine Dataset', fontsize=20)
plt.ylabel("ml")
plt.xlabel("Quality")
plt.tight_layout()

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 5 (manually graded)
#
# In the video "Using Subplots with Pandas", the following chart plotted the average of each input column as a function of the abalone target column "Rings".
# Reproduce that chart with the red wine data set using its target column instead.
#
# ![](data:image/png;base64,...)

# %%
# YOUR CHANGES HERE

...
# Out:
# Ellipsis

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 6 (manually graded)
#
# Plot the correlation matrix of the red wine data set as a heat map.

# %% [markdown]
# Hint: this visualization was performed for the Palmer penguins data set in the video "Quick Visualizations pf the Palmer Penguins.

# %%
# YOUR CHANGES HERE

corr_matrix = red_wine.corr(method='pearson')
corr_matrix.style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_cfda9_row0_col0, #T_cfda9_row1_col1, #T_cfda9_row2_col2, #T_cfda9_row3_col3, #T_cfda9_row4_col4, #T_cfda9_row5_col5, #T_cfda9_row6_col6, #T_cfda9_row7_col7, #T_cfda9_row8_col8, #T_cfda9_row9_col9, #T_cfda9_row10_col10, #T_cfda9_row11_col11 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row0_col1, #T_cfda9_row4_col11, #T_cfda9_row9_col1 {
#   background-color: #30cfff;
#   color: #000000;
# }
# #T_cfda9_row0_col2 {
#   background-color: #c936ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row0_col3, #T_cfda9_row4_col10 {
#   background-color: #2fd0ff;
#   color: #000000;
# }
# #T_cfda9_row0_col4 {
#   background-color: #48b7ff;
#   color: #000000;
# }
# #T_cfda9_row0_col5, #T_cfda9_row0_col8, #T_cfda9_row1_col2, #T_cfda9_row1_col9, #T_cfda9_row1_col11, #T_cfda9_row2_col1, #T_cfda9_row7_col10, #T_cfda9_row8_col0, #T_cfda9_row8_col3, #T_cfda9_row8_col4, #T_cfda9_row10_col6, #T_cfda9_row10_col7 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_cfda9_row0_col6 {
#   background-color: #13ecff;
#   color: #000000;
# }
# #T_cfda9_row0_col7 {
#   background-color: #c738ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row0_col9, #T_cfda9_row3_col8 {
#   background-color: #5aa5ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row0_col10, #T_cfda9_row3_col11 {
#   background-color: #4ab5ff;
#   color: #000000;
# }
# #T_cfda9_row0_col11, #T_cfda9_row2_col4, #T_cfda9_row7_col1, #T_cfda9_row7_col4, #T_cfda9_row10_col0 {
#   background-color: #5ea1ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row1_col0, #T_cfda9_row3_col4, #T_cfda9_row5_col3 {
#   background-color: #40bfff;
#   color: #000000;
# }
# #T_cfda9_row1_col3, #T_cfda9_row2_col5 {
#   background-color: #14ebff;
#   color: #000000;
# }
# #T_cfda9_row1_col4 {
#   background-color: #42bdff;
#   color: #000000;
# }
# #T_cfda9_row1_col5 {
#   background-color: #1fe0ff;
#   color: #000000;
# }
# #T_cfda9_row1_col6 {
#   background-color: #3bc4ff;
#   color: #000000;
# }
# #T_cfda9_row1_col7 {
#   background-color: #58a7ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row1_col8 {
#   background-color: #8b74ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row1_col10 {
#   background-color: #32cdff;
#   color: #000000;
# }
# #T_cfda9_row2_col0 {
#   background-color: #ce31ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row2_col3, #T_cfda9_row3_col9, #T_cfda9_row5_col4, #T_cfda9_row11_col7 {
#   background-color: #36c9ff;
#   color: #000000;
# }
# #T_cfda9_row2_col6, #T_cfda9_row7_col8 {
#   background-color: #33ccff;
#   color: #000000;
# }
# #T_cfda9_row2_col7 {
#   background-color: #936cff;
#   color: #f1f1f1;
# }
# #T_cfda9_row2_col8, #T_cfda9_row9_col3 {
#   background-color: #15eaff;
#   color: #000000;
# }
# #T_cfda9_row2_col9 {
#   background-color: #748bff;
#   color: #f1f1f1;
# }
# #T_cfda9_row2_col10, #T_cfda9_row6_col1, #T_cfda9_row7_col3 {
#   background-color: #6798ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row2_col11 {
#   background-color: #718eff;
#   color: #f1f1f1;
# }
# #T_cfda9_row3_col0 {
#   background-color: #7986ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row3_col1 {
#   background-color: #5ba4ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row3_col2, #T_cfda9_row5_col8 {
#   background-color: #728dff;
#   color: #f1f1f1;
# }
# #T_cfda9_row3_col5 {
#   background-color: #4bb4ff;
#   color: #000000;
# }
# #T_cfda9_row3_col6, #T_cfda9_row6_col0 {
#   background-color: #56a9ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row3_col7 {
#   background-color: #916eff;
#   color: #f1f1f1;
# }
# #T_cfda9_row3_col10 {
#   background-color: #5ca3ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row4_col0, #T_cfda9_row9_col11 {
#   background-color: #7689ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row4_col1 {
#   background-color: #659aff;
#   color: #f1f1f1;
# }
# #T_cfda9_row4_col2 {
#   background-color: #7c83ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row4_col3 {
#   background-color: #21deff;
#   color: #000000;
# }
# #T_cfda9_row4_col5 {
#   background-color: #23dcff;
#   color: #000000;
# }
# #T_cfda9_row4_col6 {
#   background-color: #35caff;
#   color: #000000;
# }
# #T_cfda9_row4_col7 {
#   background-color: #7788ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row4_col8, #T_cfda9_row5_col9, #T_cfda9_row6_col4 {
#   background-color: #3fc0ff;
#   color: #000000;
# }
# #T_cfda9_row4_col9, #T_cfda9_row9_col4, #T_cfda9_row11_col2 {
#   background-color: #807fff;
#   color: #f1f1f1;
# }
# #T_cfda9_row5_col0 {
#   background-color: #50afff;
#   color: #f1f1f1;
# }
# #T_cfda9_row5_col1 {
#   background-color: #59a6ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row5_col2, #T_cfda9_row5_col7 {
#   background-color: #51aeff;
#   color: #f1f1f1;
# }
# #T_cfda9_row5_col6 {
#   background-color: #b946ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row5_col10, #T_cfda9_row9_col8 {
#   background-color: #49b6ff;
#   color: #000000;
# }
# #T_cfda9_row5_col11 {
#   background-color: #3ec1ff;
#   color: #000000;
# }
# #T_cfda9_row6_col2 {
#   background-color: #609fff;
#   color: #f1f1f1;
# }
# #T_cfda9_row6_col3 {
#   background-color: #44bbff;
#   color: #000000;
# }
# #T_cfda9_row6_col5 {
#   background-color: #b649ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row6_col7 {
#   background-color: #619eff;
#   color: #f1f1f1;
# }
# #T_cfda9_row6_col8 {
#   background-color: #5da2ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row6_col9, #T_cfda9_row8_col11 {
#   background-color: #3dc2ff;
#   color: #000000;
# }
# #T_cfda9_row6_col10, #T_cfda9_row8_col5 {
#   background-color: #31ceff;
#   color: #000000;
# }
# #T_cfda9_row6_col11 {
#   background-color: #25daff;
#   color: #000000;
# }
# #T_cfda9_row7_col0 {
#   background-color: #cd32ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row7_col2 {
#   background-color: #9768ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row7_col5, #T_cfda9_row8_col6 {
#   background-color: #1de2ff;
#   color: #000000;
# }
# #T_cfda9_row7_col6 {
#   background-color: #3ac5ff;
#   color: #000000;
# }
# #T_cfda9_row7_col9 {
#   background-color: #53acff;
#   color: #f1f1f1;
# }
# #T_cfda9_row7_col11 {
#   background-color: #27d8ff;
#   color: #000000;
# }
# #T_cfda9_row8_col1 {
#   background-color: #817eff;
#   color: #f1f1f1;
# }
# #T_cfda9_row8_col2 {
#   background-color: #01feff;
#   color: #000000;
# }
# #T_cfda9_row8_col7, #T_cfda9_row11_col1 {
#   background-color: #1ae5ff;
#   color: #000000;
# }
# #T_cfda9_row8_col9 {
#   background-color: #0df2ff;
#   color: #000000;
# }
# #T_cfda9_row8_col10 {
#   background-color: #7887ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row9_col0 {
#   background-color: #837cff;
#   color: #f1f1f1;
# }
# #T_cfda9_row9_col2 {
#   background-color: #8e71ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row9_col5 {
#   background-color: #2dd2ff;
#   color: #000000;
# }
# #T_cfda9_row9_col6 {
#   background-color: #34cbff;
#   color: #000000;
# }
# #T_cfda9_row9_col7 {
#   background-color: #6e91ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row9_col10 {
#   background-color: #649bff;
#   color: #f1f1f1;
# }
# #T_cfda9_row10_col1 {
#   background-color: #39c6ff;
#   color: #000000;
# }
# #T_cfda9_row10_col2 {
#   background-color: #6d92ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row10_col3 {
#   background-color: #1ee1ff;
#   color: #000000;
# }
# #T_cfda9_row10_col4 {
#   background-color: #08f7ff;
#   color: #000000;
# }
# #T_cfda9_row10_col5 {
#   background-color: #12edff;
#   color: #000000;
# }
# #T_cfda9_row10_col8 {
#   background-color: #8778ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row10_col9 {
#   background-color: #47b8ff;
#   color: #000000;
# }
# #T_cfda9_row10_col11 {
#   background-color: #9f60ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row11_col0 {
#   background-color: #7a85ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row11_col3 {
#   background-color: #17e8ff;
#   color: #000000;
# }
# #T_cfda9_row11_col4 {
#   background-color: #1be4ff;
#   color: #000000;
# }
# #T_cfda9_row11_col5 {
#   background-color: #16e9ff;
#   color: #000000;
# }
# #T_cfda9_row11_col6 {
#   background-color: #04fbff;
#   color: #000000;
# }
# #T_cfda9_row11_col8 {
#   background-color: #5fa0ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row11_col9 {
#   background-color: #6897ff;
#   color: #f1f1f1;
# }
# #T_cfda9_row11_col10 {
#   background-color: #a659ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cfda9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfda9_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_cfda9_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_cfda9_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_cfda9_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_cfda9_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_cfda9_

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 7 (manually graded)
#
# Plot a box plot of the alcohol column grouping the data by the target column.

# %%
# YOUR CHANGES HERE

red_wine.boxplot("alcohol", by="target",
                 figsize=(10, 7),
                 grid=True,
                 color='violet')
plt.suptitle('Alcohol Content by Wine Quality', fontsize=20)
plt.xlabel('Quality')
plt.ylabel('Alcohol % by Volume')
# Out:
# Text(0, 0.5, 'Alcohol % by Volume')

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 8 (manually graded)
#
# Hexagonal bin plots are an alternative to scatter plots that helps visualize density instead of individual points.
# Make a hexagonal bin plot of the residual sugar and alcohol in the red wine data set.

# %% [markdown]
# Hint: pandas has built-in support for hexagonal bin plots.
# The default grid size that pandas uses is fairly small, so you may want to adjust it to your taste.

# %%
# YOUR CHANGES HERE

red_wine.plot.hexbin(x='residual sugar', y='alcohol', 
                     gridsize=25, cmap='Blues', figsize=(10, 7))
# Out:
# <Axes: xlabel='residual sugar', ylabel='alcohol'>

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 9 (manually graded)
#
# Make a scatter plot of the red wine data set's target column and each of the other columns in that data set.
# Make one chart for each of the other columns.

# %%
# YOUR CHANGES HERE

red_wine.plot.scatter(x='target', y='fixed acidity', figsize=(10, 7), color='green')
# Out:
# <Axes: xlabel='target', ylabel='fixed acidity'>

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 10 (manually graded)
#
# Pick a pair of input columns in the red wine data set that looks interesting when colored by the target column.
# By interesting, the target values (colors) should be visibly different for some combination of your chosen input columns.

# %% [markdown]
# Hint: use scatter matrix to investigate possible columns, but don't leave it in your notebook as it will make the autograder very slow.

# %%
# YOUR CHANGES HERE

...
# Out:
# Ellipsis

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 11 (automatically graded)
#
# Set `p11` to the value of $(3 + \mathrm{sin}(2))^5$.

# %%
# YOUR CHANGES HERE

p11 = (3+np.sin(2)) ** 5

# %%
p11
# Out:
# np.float64(913.0479132098069)

# %% [markdown]
# ### Problem 12 (automatically graded)
#
# Write a function `p12` that takes in a sequence of strings and returns a list of the strings starting with the prefix "input_".
# The list should be in the same order as the input sequence.

# %%
# YOUR CHANGES HERE

def p12(column_names):
    return [name for name in column_names if name.startswith("input_")]

# %%
# should return ["input_0", "input_1"]
p12(["input_0", "input_1", "target"])
# Out:
# ['input_0', 'input_1']

# %% [markdown]
# ### Problem 13 (automatically graded)
#
# Sort the list `p13` so that the tuples are sorted in order of their second entry (the strings).

# %%
# DO NOT CHANGE

p13 = [(0, "zebra"), (1, "yellow"), (2, "xylophone"), (3, "dog"), (4, "elephant"), (5, "apple")]

# %%
# YOUR CHANGES HERE

p13.sort(key=lambda pair: pair[1])

# %% [markdown]
# ### Problem 14 (automatically graded)
#
# Set `p14` to be a string with the value of the mathematical constant $\pi$ showing exactly 8 digits after the decimal point (include zeros as necessary).
# For your convenience, `q14` has a copy of $\pi$.

# %%
# DO NOT CHANGE

q14 = math.pi
q14
# Out:
# 3.141592653589793

# %%
# YOUR CHANGES HERE

p14 = f"{q14:.8f}"

# %%
p14
# Out:
# '3.14159265'

# %% [markdown]
# ### Problem 15 (automatically graded)
#
# Plot the data in variables `x15` and `y15` as a line chart and save it to the file `p15.png`.

# %%
# DO NOT CHANGE

x15 = np.linspace(-10, 10)
y15 = x15 ** 2 - 2 * x15 + 1

# %%
# YwwwwwOUR CHANGES HERE

plt.plot(x15, y15, color='orange', linewidth=2)
plt.title('Quadratic Function: y = x^2 - 2x + 1', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.grid(True)

# %% [markdown]
# ### Problem 16 (automatically graded)
#
# Set `p16` to be a $253 \times 512$ NumPy array filled entirely with the number 42.

# %%
# YOUR CHANGES HERE

p16 = np.full((253, 512), 42)

# %% [markdown]
# ### Problem 17 (automatically graded)
#
# Set `p17` to be a view of array `q17` that has size $1000000 \times 3$ where each row is a copy of `q17`.

# %% [markdown]
# Hint: use broadcasting.

# %%
# DO NOT CHANGE

q17 = np.array([1, 3, 5])
q17
# Out:
# array([1, 3, 5])

# %%
# YOUR CHANGES HERE

p17 = ...

# %%
p17
# Out:
# Ellipsis

# %% [markdown]
# ### Problem 18 (automatically graded)
#
# Set `p18` to be a Pandas series with the mean of each column of the red wine data set.
# The index of `p18` should be the column names of the red wine data set.

# %%
# YOUR CHANGES HERE

p18 = ...

# %%
p18
# Out:
# Ellipsis

# %% [markdown]
# ### Problem 19 (automatically graded)
#
# The data frame in `q19` contains the first names of actors and their hometowns.
# Set `p19` to be a data frame of pairs of actors with the same hometown.
# `p19` should have two columns, `name_1` and `name_2` and the value in `name_1` should before the value in `name_2` to avoid matching an actor with themselves and repeating a pair with both orders.

# %%
# DO NOT CHANGE

q19 = pd.DataFrame({"name": ["Mel", "John", "Tom", "Benjamin", "Michael", "Emily", "Tom"],
                    "hometown": ["Peekskill", "Newton", "Concord", "Newton", "Newton", "London", "London"]})
q19
# Out:
#        name   hometown
# 0       Mel  Peekskill
# 1      John     Newton
# 2       Tom    Concord
# 3  Benjamin     Newton
# 4   Michael     Newton
# 5     Emily     London
# 6       Tom     London

# %%
# YOUR CHANGES HERE

...
# Out:
# Ellipsis

# %% [markdown]
# ### Problem 20 (automatically graded)
#
# Set `p20` to be a data frame with data from the red wine data set indexed on its target where each column has the mean values for that column and target value.
# `p20` should have a column for each of the input columns of the red wine data set.

# %%
# YOUR CHANGES HERE

...
# Out:
# Ellipsis
